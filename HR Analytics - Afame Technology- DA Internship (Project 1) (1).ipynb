# %% [markdown]
# # HR Analytics
# Activities to complete =>>
# Data cleansing involves removing unnecessary columns.
# Giving the columns new names.
# Eliminating redundant entries.
# sanitizing specific columns.
# Eliminate the dataset's NaN values.
# Look for a few more changes if necessary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('C:/Users/Shivaleela Koodlappa/Downloads/HR Data.csv')
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
data.describe(include="O")
# Out:
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
#                 JobRole MaritalStatus Over18 OverTime
# count              1470          1470   1470     1470
# unique                9             3      1        2
# top     Sales Executive       Married      Y       No
# freq                326           673   1470     1054

# %%
data.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeCount  \
# 0                False      False           False          False
# 1                False      False           False          False
# ...

# %%
print(data['Attrition'].value_counts())
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %% [markdown]
# The people who are not willing to leave the job is 1233 and the people who are willing to leave the job is 237

# %%
print(data.dropna(inplace=True))
#there are no missing values that we want want make it true
# Out:
# None

# %%
dupli_row = data.duplicated()
print("Number of duplicated rows ",dupli_row.sum())
#there are no duplicated rows
# Out:
# Number of duplicated rows  0

# %% [markdown]
# Visualizing and analyzing the data
# target column = attrition

# %%
import seaborn as sns
sns.countplot(x=data.Attrition)
plt.show()

# %%
#impact pf buisness travel on Attrtion
sns.countplot(hue=data.Attrition,x=data.BusinessTravel)
plt.show()

# %%
#impact of education feild on Attrition
sns.countplot(x=data.Attrition,hue=data.EducationField)
plt.show()

#people from life science has highest

# %%
#gender and attrition
sns.countplot(x=data.Attrition,hue=data.Gender)
plt.show()

# %%
#inthe above visualization overtime is not effecting attrition and there are less number of people who are doing overtime
#Now Impact of job role on attrition 
plt.figure(figsize=(20,10),facecolor = "white")
sns.countplot(x='JobRole',hue="Attrition",data=data)
plt.xlabel('Jobrole',fontsize=10)
plt.show()

# %%
sns.histplot(hue=data.Attrition,x=data.Age)
plt.show()

# %%
#distance from home and attrition
sns.histplot(hue=data.Attrition,x=data.DistanceFromHome)
plt.show()

# %%
#how monthly income gives trends with respect to attrition
sns.histplot(x=data.MonthlyIncome,hue=data.Attrition)
plt.show()

# %% [markdown]
# Higher income the person will not leave the job ,lower the income higher the people leaving the job

# %%
#Now will see the impact of Number of companies worked 
sns.histplot(x=data.NumCompaniesWorked,hue=data.Attrition)
plt.show()

# %% [markdown]
# In the above graph ,we can observe that The employee who worked before in 1 or 2 company and more
# (0,2,4,6... are the number of companies)
# the employess who worked in one company has the more impact on the attrition

# %%
#how salary hike is impacting the attrition
sns.histplot(hue=data.Attrition,x=data.PercentSalaryHike)
plt.show()

# %% [markdown]
# So we can say that higher the salary hike lesser the Attrition

# %%
#years at the company
sns.histplot(hue=data.Attrition,x=data.YearsAtCompany)
plt.show()

# %% [markdown]
# By viewing above graph we can say that ,Generally 50% of freshers tends to leave the comany also around people who are ranging from 1 to 10 years ,they might leave the company

# %% [markdown]
# We have done continous column analysis

# %%
#Analysis of descrete data with respect to target column 
discrete_col = []
for col in data.columns:
    if data[col].dtype == "int64" and len(data[col].unique()) <=10:
        discrete_col.append(col)
print(discrete_col)
# Out:
# ['Education', 'EmployeeCount', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'NumCompaniesWorked', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance']

# %%
data3=data[['Education', 'EmployeeCount', 
            'EnvironmentSatisfaction', 'JobInvolvement', 
            'JobLevel', 'JobSatisfaction', 
            'NumCompaniesWorked', 'PerformanceRating',
            'RelationshipSatisfaction', 'StandardHours', 
            'StockOptionLevel', 'TrainingTimesLastYear', 'WorkLifeBalance']]

# %%
#Graphical Representation
plt.figure(figsize=(20,25),facecolor='white')
plotnumber = 1
for col in data3:
    if plotnumber<=16:
        ax = plt.subplot(4,4,plotnumber)
        sns.countplot(x=data3[col].dropna(axis=0)
                     ,hue=data.Attrition)
        plt.xlabel(col,fontsize=20)
        plt.ylabel('Attrition',fontsize=20)
    plotnumber +=1
plt.tight_layout()

# %%
# Import label encoder 
from sklearn import preprocessing 
    
# label_encoder object knows how  
# to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
obj = (data.dtypes == 'object') 
for col in list(obj[obj].index): 
  data[col] = label_encoder.fit_transform(data[col])

# %%
 #To find the number of columns with  
# datatype==object 
obj = (data.dtypes == 'object') 
print("Categorical variables:",len(list(obj[obj].index)))
# Out:
# Categorical variables: 0

# %%
'''plt.figure(figsize=(12,6)) 
  
sns.heatmap(data.corr(),cmap='BrBG',fmt='.2f', 
            linewidths=2,annot=True)
            '''
# Out:
# "plt.figure(figsize=(12,6)) \n  \nsns.heatmap(data.corr(),cmap='BrBG',fmt='.2f', \n            linewidths=2,annot=True)\n            "

# %%
from sklearn.model_selection import train_test_split
X=data.drop(['Attrition'],axis=1)
y=data['Attrition']
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.4, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (882, 34)
# (588, 34)
# (882,)
# (588,)

# %% [markdown]
# Model trainig and predicting

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import metrics 
clf = DecisionTreeClassifier(criterion = 'entropy',max_depth = 3)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
accuracy = metrics.accuracy_score(y_test,y_pred)

print('Accuracy is :',round(accuracy*100,2),'%')
# Out:
# Accuracy is : 87.24 %

# %% [markdown]
# By the Accuracy that we got from Decision tree classifier
# We can Say that Around 87% employees may not leave the company but remaining 13% employees are likely to leave the company.
